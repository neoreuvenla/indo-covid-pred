# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('covid_19_indonesia_time_series_all.csv')
df.head()
# Out:
#        Date Location ISO Code     Location  New Cases  New Deaths  \
# 0  3/1/2020             ID-JK  DKI Jakarta          2           0
# 1  3/2/2020             ID-JK  DKI Jakarta          2           0
# 2  3/2/2020               IDN    Indonesia          2           0
# 3  3/2/2020             ID-RI         Riau          1           0
# 4  3/3/2020             ID-JK  DKI Jakarta          2           0
#
#    New Recovered  New Active Cases  Total Cases  Total Deaths  \
# 0              0                 2           39            20
# 1              0                 2           41            20
# 2              0                 2            2             0
# 3              0                 1            2             0
# 4              0                 2           43            20
#
#    Total Recovered  ...  Latitude New Cases per Million  \
# 0               41  ... -6.204699                  0.18
# 1               41  ... -6.204699                  0.18
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'], format="%m/%d/%Y")
df['Case Fatality Rate'] = df['Case Fatality Rate'].str.rstrip('%').astype('float') / 100.0
df['Case Recovered Rate'] = df['Case Recovered Rate'].str.rstrip('%').astype('float') / 100.0
df.head()
# Out:
#         Date Location ISO Code     Location  New Cases  New Deaths  \
# 0 2020-03-01             ID-JK  DKI Jakarta          2           0
# 1 2020-03-02             ID-JK  DKI Jakarta          2           0
# 2 2020-03-02               IDN    Indonesia          2           0
# 3 2020-03-02             ID-RI         Riau          1           0
# 4 2020-03-03             ID-JK  DKI Jakarta          2           0
#
#    New Recovered  New Active Cases  Total Cases  Total Deaths  \
# 0              0                 2           39            20
# 1              0                 2           41            20
# 2              0                 2            2             0
# 3              0                 1            2             0
# 4              0                 2           43            20
#
#    Total Recovered  ...  Latitude New Cases per Million  \
# 0               41  ... -6.204699                  0.18
# 1               41  ... -6.204699                  0.18
# ...

# %%
df.corr()
# Out:
#                              New Cases  New Deaths  New Recovered  \
# New Cases                     1.000000    0.883605       0.896256
# New Deaths                    0.883605    1.000000       0.937687
# New Recovered                 0.896256    0.937687       1.000000
# New Active Cases              0.229723   -0.125791      -0.225616
# Total Cases                   0.558409    0.591411       0.630925
# Total Deaths                  0.488417    0.552839       0.569523
# Total Recovered               0.510819    0.546664       0.587108
# Total Active Cases            0.950248    0.921230       0.942956
# City or Regency                    NaN         NaN            NaN
# Total Regencies               0.523871    0.485562       0.524084
# Total Cities                  0.531516    0.489005       0.531895
# Total Districts               0.527537    0.489060       0.527747
# Total Urban Villages          0.529095    0.489594       0.529369
# ...

# %%
mask = np.triu(df.corr())
plt.style.use('seaborn')
fg, ax = plt.subplots(figsize=(18, 7), dpi=200)
sns.heatmap(df.corr(), mask=mask, cmap='Reds', annot=True, linewidths=1)
plt.title('KORELASI TIAP FEATURE', fontweight='bold', fontsize=20)
plt.xticks(rotation=30)
plt.show()

# %%
#df2 = df[["Location","New Cases", "New Deaths", "New Recovered", "New Active Cases", "Total Cases", "Total Deaths", "Total Recovered", "Total Active Cases", "Population", "Population Density", "New Cases per Million", "Case Fatality Rate", "Case Recovered Rate", "Growth Factor of New Cases"]]
df2 = df[df['Location'] != "Indonesia"] 

x=df2["Population Density"]
y=df2["New Cases per Million"]

plt.scatter(x,y)
plt.semilogx()
# Out:
# []

# %%
df2.corr()
# Out:
#                              New Cases  New Deaths  New Recovered  \
# New Cases                     1.000000    0.661132       0.803703
# New Deaths                    0.661132    1.000000       0.658415
# New Recovered                 0.803703    0.658415       1.000000
# New Active Cases              0.189344   -0.115977      -0.431502
# Total Cases                   0.466974    0.393828       0.491649
# Total Deaths                  0.336677    0.476010       0.360778
# Total Recovered               0.417704    0.350472       0.449934
# Total Active Cases            0.858331    0.658097       0.769998
# City or Regency                    NaN         NaN            NaN
# Total Regencies               0.070166    0.208817       0.057977
# Total Cities                  0.284973    0.279835       0.258467
# Total Districts               0.185919    0.273907       0.164778
# Total Urban Villages          0.231310    0.283430       0.207630
# ...

# %%
#mask = np.triu(df2.corr())
plt.style.use('seaborn')
fg, ax = plt.subplots(figsize=(18, 7), dpi=200)
sns.heatmap(df2.corr(), cmap='Reds', annot=True, linewidths=1)
plt.title('Filtered Dataset Correlations', fontweight='bold', fontsize=20)
plt.xticks(rotation=30)
plt.show()
